# %% [markdown]
# ### Questions to Answer
# (Respective datasets in parentheses)
#
# 1. Which counties have the highest percentage of occupied housing tracts enrolled in SNAP? (Food Access Research Atlas)
#
# 2. What are the demographics of those counties? (Food Access Research Atlas) What about regions? (Food Access Research Atlas)
#
# 3. Do more seniors or kids live in areas with low access to food? (Food Access Research Atlas)
#
# 4. Are the counties with highest percentages of SNAP enrollments also the counties with the highest percentages of food insecurity? (Food Access Research Atlas)
#
# 5. Which counties have the highest/lowest disparities in food access among census tracts? Of those counties, how do the min/max food insecure tract demographics compare? (Food Access Research Atlas)
#
# 6. Do counties with the highest levels of income disparity tend to have higher percentages of food insecurity? (Food Access Research Atlas and Census Household Income)
#
# 7. Of the counties with the highest levels of food insecurity, what percentage of these tracts are in the lowest income brackets? (Food Access Research Atlas and Census Household Income)
#
# 8. Of the counties with the highest levels of food insecurity, what does spending for children’s programs look like? How has it changed over time? What about counties with the lowest levels of food insecurity? (TN Children Served)
#
# 9. What are the highest enrollments for children's programs? highest expenditures? and highest expenditures per child? (TN Children Served)
#
# 10. Which counties/programs have more reliable data? Look at “actual” vs “estimate”, NaN and outlier values for children served/expenditures. (TN Children Served)
#
# 11. How much do counties spend on SNAP and other food programs? How does that correlate with a county’s total SNAP enrollment? (Food Access Research Atlas and TN Children Served)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
tn_food_access_df = pd.read_excel('../data/tn_food_access_clean_excel.xlsx')

# %%
tn_food_access_df.head()
# Out:
#        ct_long    county     county_and_state region      state  \
# 0  47001020100  Anderson  Anderson, Tennessee   East  Tennessee
# 1  47001020201  Anderson  Anderson, Tennessee   East  Tennessee
# 2  47001020202  Anderson  Anderson, Tennessee   East  Tennessee
# 3  47001020300  Anderson  Anderson, Tennessee   East  Tennessee
# 4  47001020400  Anderson  Anderson, Tennessee   East  Tennessee
#
#                     country  Urban  Pop2010  OHU2010  TractLOWI  ...  \
# 0  United States of America      1     3111     1546       1381  ...
# 1  United States of America      1     3670     1535        604  ...
# 2  United States of America      1     4507     2025       1741  ...
# 3  United States of America      1     3822     1656       1077  ...
# 4  United States of America      1     4508     2013       1995  ...
#
#    laaian20  laaian20share  laomultir20  laomultir20share  lahisp20  \
# 0       NaN            NaN          NaN               NaN       NaN
# 1       NaN            NaN          NaN               NaN       NaN
# 2       NaN            NaN          NaN               NaN       NaN
# 3       NaN            NaN          NaN               NaN       NaN
# 4       NaN            NaN          NaN               NaN       NaN
#
#    lahisp20share  lahunv20  lahunv20share  lasnap20  lasnap20share
# 0            NaN       NaN            NaN       NaN            NaN
# 1            NaN       NaN            NaN       NaN            NaN
# 2            NaN       NaN            NaN       NaN            NaN
# 3            NaN       NaN            NaN       NaN            NaN
# 4            NaN       NaN            NaN       NaN            NaN
#
# [5 rows x 150 columns]

# %% [markdown]
# 1. Which counties have the highest percentage of occupied housing units enrolled in SNAP? (Food Access Research Atlas)

# %% [markdown]
# `TractSNAP` - Total count of housing units receiving SNAP benefits in tract
#
# `county_and_state` groupby
#
# `OHU2010` - Occupied housing unit count from 2010 census

# %%
tn_food_access_df['pct_ohu_snap'] = round((tn_food_access_df['TractSNAP']/tn_food_access_df['OHU2010']*100),2)

# %%
tn_food_access_df.head()
# Out:
#        ct_long    county     county_and_state region      state  \
# 0  47001020100  Anderson  Anderson, Tennessee   East  Tennessee
# 1  47001020201  Anderson  Anderson, Tennessee   East  Tennessee
# 2  47001020202  Anderson  Anderson, Tennessee   East  Tennessee
# 3  47001020300  Anderson  Anderson, Tennessee   East  Tennessee
# 4  47001020400  Anderson  Anderson, Tennessee   East  Tennessee
#
#                     country  Urban  Pop2010  OHU2010  TractLOWI  ...  \
# 0  United States of America      1     3111     1546       1381  ...
# 1  United States of America      1     3670     1535        604  ...
# 2  United States of America      1     4507     2025       1741  ...
# 3  United States of America      1     3822     1656       1077  ...
# 4  United States of America      1     4508     2013       1995  ...
#
#    laaian20share  laomultir20  laomultir20share  lahisp20  lahisp20share  \
# 0            NaN          NaN               NaN       NaN            NaN
# 1            NaN          NaN               NaN       NaN            NaN
# 2            NaN          NaN               NaN       NaN            NaN
# 3            NaN          NaN               NaN       NaN            NaN
# 4            NaN          NaN               NaN       NaN            NaN
#
#    lahunv20  lahunv20share  lasnap20  lasnap20share  pct_ohu_snap
# 0       NaN            NaN       NaN            NaN         28.33
# 1       NaN            NaN       NaN            NaN          2.02
# 2       NaN            NaN       NaN            NaN         10.27
# 3       NaN            NaN       NaN            NaN          6.58
# 4       NaN            NaN       NaN            NaN         20.17
#
# [5 rows x 151 columns]

# %%
pct_ohu_snap_by_county = round((tn_food_access_df.groupby('county_and_state')['pct_ohu_snap'].mean()),2)

# %%
print(pct_ohu_snap_by_county)
# Out:
# county_and_state
# Anderson, Tennessee      16.92
# Bedford, Tennessee       15.75
# Benton, Tennessee        19.09
# Bledsoe, Tennessee       27.56
# Blount, Tennessee        12.97
#                          ...
# Wayne, Tennessee         16.72
# Weakley, Tennessee       19.09
# White, Tennessee         17.61
# Williamson, Tennessee     3.13
# Wilson, Tennessee        10.29
# Name: pct_ohu_snap, Length: 95, dtype: float64

# %%
pct_ohu_snap_by_county_df = pd.DataFrame(pct_ohu_snap_by_county).reset_index()

# %%
# using earlier code for reference:
# tn_food_access_df[tn_food_access_df['Pop2010'].iloc[:]==tn_food_access_df['Pop2010'].iloc[:].min()]

pct_ohu_snap_by_county_df[pct_ohu_snap_by_county_df['pct_ohu_snap'].iloc[:]==pct_ohu_snap_by_county_df['pct_ohu_snap'].iloc[:].min()]
# Out:
#          county_and_state  pct_ohu_snap
# 93  Williamson, Tennessee          3.13

# %%
pct_ohu_snap_by_county_df[pct_ohu_snap_by_county_df['pct_ohu_snap'].iloc[:]==pct_ohu_snap_by_county_df['pct_ohu_snap'].iloc[:].max()]
# Out:
#    county_and_state  pct_ohu_snap
# 47  Lake, Tennessee         36.79

# %%
food_dict= {
    
}

# %%
ax = sns.histplot(pct_ohu_snap_by_county_df, bins=50, color='#06470c', legend=False)
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
ax.patch.set_alpha(0.5)
plt.xlabel('OHU Enrolled in SNAP (%)')
plt.ylabel('# of Counties')
plt.savefig('snapbycounty2.png', transparent=True)
# plt.savefig('snapbycounty3.png')

# %%
highest_snap_counties = pct_ohu_snap_by_county_df.sort_values(by='pct_ohu_snap', ascending=False)

# %%
# highest_snap_counties.to_csv('highest_snap_counties.csv')

# %%
pct_ohu_snap_by_county_median = round((tn_food_access_df.groupby('county_and_state')['pct_ohu_snap'].median()),2)

# %%
pct_ohu_snap_by_county_median_df = pd.DataFrame(pct_ohu_snap_by_county_median).reset_index()

# %%
pct_ohu_snap_by_county_median_df[pct_ohu_snap_by_county_median_df['pct_ohu_snap'].iloc[:]==pct_ohu_snap_by_county_median_df['pct_ohu_snap'].iloc[:].max()]
# Out:
#    county_and_state  pct_ohu_snap
# 47  Lake, Tennessee         36.79

# %%
pct_ohu_snap_by_county_median_df[pct_ohu_snap_by_county_median_df['pct_ohu_snap'].iloc[:]==pct_ohu_snap_by_county_median_df['pct_ohu_snap'].iloc[:].min()]
# Out:
#          county_and_state  pct_ohu_snap
# 93  Williamson, Tennessee          1.14

# %% [markdown]
# Taking a look at percentage of occupied housing units enrolled in SNAP by region now:

# %%
pct_ohu_snap_by_region = round((tn_food_access_df.groupby('region')['pct_ohu_snap'].mean()),2)

# %%
pct_ohu_snap_by_region_df = pd.DataFrame(pct_ohu_snap_by_region).reset_index()

# %%
pct_ohu_snap_by_region_df
# Out:
#    region  pct_ohu_snap
# 0    East         16.14
# 1  Middle         13.21
# 2    West         19.96

# %%
ax = sns.barplot(data=pct_ohu_snap_by_region_df, x='region',y='pct_ohu_snap', color='#06470c')
ax.set(xlabel=None)
ax.set(ylabel='Average OHU in SNAP (%)')
# plt.savefig('by_region_3.png',transparent=True)

# %%
pct_ohu_snap_by_region_median = round((tn_food_access_df.groupby('region')['pct_ohu_snap'].median()),2)

# %%
pct_ohu_snap_by_region_median_df = pd.DataFrame(pct_ohu_snap_by_region_median).reset_index()

# %%
ax = sns.barplot(data=pct_ohu_snap_by_region_median_df, x='region',y='pct_ohu_snap', color='#06470c')
ax.set(xlabel=None)
ax.set(ylabel='Median OHU in SNAP (%)')
# plt.savefig('by_region.png',transparent=True)
# Out:
# [Text(0, 0.5, 'Median OHU in SNAP (%)')]

# %% [markdown]
# Just did a little Excel magic to the previously-downloaded list of SNAP enrollment by county to add region! Reading it back in here:

# %%
counties_and_regions_by_pct_ohu_snap_df = pd.read_csv('../data/highest_snap_counties.csv')

# %%
counties_and_regions_by_pct_ohu_snap_df.head(10)
# Out:
#         county_and_state      county  region  pct_ohu_snap
# 0        Lake, Tennessee        Lake    West         36.79
# 1     Hancock, Tennessee     Hancock    East         28.69
# 2       Scott, Tennessee       Scott    East         28.64
# 3     Bledsoe, Tennessee     Bledsoe    East         27.56
# 4       Union, Tennessee       Union    East         26.32
# 5    Fentress, Tennessee    Fentress  Middle         25.71
# 6      Morgan, Tennessee      Morgan    East         25.40
# 7  Lauderdale, Tennessee  Lauderdale    West         24.98
# 8     Pickett, Tennessee     Pickett  Middle         23.98
# 9     Haywood, Tennessee     Haywood    West         23.04

# %%
counties_and_regions_by_pct_ohu_snap_df.tail(10)
# Out:
#          county_and_state      county  region  pct_ohu_snap
# 85     Dickson, Tennessee     Dickson  Middle         11.95
# 86     Overton, Tennessee     Overton  Middle         11.86
# 87    Cheatham, Tennessee    Cheatham  Middle         11.79
# 88  Rutherford, Tennessee  Rutherford  Middle         10.97
# 89   Humphreys, Tennessee   Humphreys  Middle         10.90
# 90      Sumner, Tennessee      Sumner  Middle         10.75
# 91      Wilson, Tennessee      Wilson  Middle         10.29
# 92       Moore, Tennessee       Moore  Middle         10.14
# 93      Loudon, Tennessee      Loudon    East          9.47
# 94  Williamson, Tennessee  Williamson  Middle          3.13

# %%
countries_and_regions_df = counties_and_regions_by_pct_ohu_snap_df

# %% [markdown]
# 2. What are the demographics of those counties? (Food Access Research Atlas) What about regions? (Food Access Research Atlas)

# %%
tn_food_access_df.head()
# Out:
#        ct_long    county     county_and_state region      state  \
# 0  47001020100  Anderson  Anderson, Tennessee   East  Tennessee
# 1  47001020201  Anderson  Anderson, Tennessee   East  Tennessee
# 2  47001020202  Anderson  Anderson, Tennessee   East  Tennessee
# 3  47001020300  Anderson  Anderson, Tennessee   East  Tennessee
# 4  47001020400  Anderson  Anderson, Tennessee   East  Tennessee
#
#                     country  Urban  Pop2010  OHU2010  TractLOWI  ...  \
# 0  United States of America      1     3111     1546       1381  ...
# 1  United States of America      1     3670     1535        604  ...
# 2  United States of America      1     4507     2025       1741  ...
# 3  United States of America      1     3822     1656       1077  ...
# 4  United States of America      1     4508     2013       1995  ...
#
#    laaian20share  laomultir20  laomultir20share  lahisp20  lahisp20share  \
# 0            NaN          NaN               NaN       NaN            NaN
# 1            NaN          NaN               NaN       NaN            NaN
# 2            NaN          NaN               NaN       NaN            NaN
# 3            NaN          NaN               NaN       NaN            NaN
# 4            NaN          NaN               NaN       NaN            NaN
#
#    lahunv20  lahunv20share  lasnap20  lasnap20share  pct_ohu_snap
# 0       NaN            NaN       NaN            NaN         28.33
# 1       NaN            NaN       NaN            NaN          2.02
# 2       NaN            NaN       NaN            NaN         10.27
# 3       NaN            NaN       NaN            NaN          6.58
# 4       NaN            NaN       NaN            NaN         20.17
#
# [5 rows x 151 columns]

# %%
tn_food_access_df['pct_LOWI'] = round((tn_food_access_df['TractLOWI']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_kids'] = round((tn_food_access_df['TractKids']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_seniors'] = round((tn_food_access_df['TractSeniors']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_white'] = round((tn_food_access_df['TractWhite']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_black'] = round((tn_food_access_df['TractBlack']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_asian'] = round((tn_food_access_df['TractAsian']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_pac_isl'] = round((tn_food_access_df['TractNHOPI']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_aian'] = round((tn_food_access_df['TractAIAN']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_o_multir'] = round((tn_food_access_df['TractOMultir']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_hispanic'] = round((tn_food_access_df['TractHispanic']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_no_vehicle'] = round((tn_food_access_df['TractHUNV']/tn_food_access_df['OHU2010']*100),2)
tn_food_access_df['pct_lapop1_10'] = round((tn_food_access_df['LAPOP1_10']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_lapop05_10'] = round((tn_food_access_df['LAPOP05_10']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_lapop1_20'] = round((tn_food_access_df['LAPOP1_20']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_lalowi1_10'] = round((tn_food_access_df['LALOWI1_10']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_lalowi05_10'] = round((tn_food_access_df['LALOWI05_10']/tn_food_access_df['Pop2010']*100),2)
tn_food_access_df['pct_lalowi1_20'] = round((tn_food_access_df['LALOWI1_20']/tn_food_access_df['Pop2010']*100),2)

# %%
tn_food_access_df.head()
# Out:
#        ct_long    county     county_and_state region      state  \
# 0  47001020100  Anderson  Anderson, Tennessee   East  Tennessee
# 1  47001020201  Anderson  Anderson, Tennessee   East  Tennessee
# 2  47001020202  Anderson  Anderson, Tennessee   East  Tennessee
# 3  47001020300  Anderson  Anderson, Tennessee   East  Tennessee
# 4  47001020400  Anderson  Anderson, Tennessee   East  Tennessee
#
#                     country  Urban  Pop2010  OHU2010  TractLOWI  ...  \
# 0  United States of America      1     3111     1546       1381  ...
# 1  United States of America      1     3670     1535        604  ...
# 2  United States of America      1     4507     2025       1741  ...
# 3  United States of America      1     3822     1656       1077  ...
# 4  United States of America      1     4508     2013       1995  ...
#
#    pct_aian  pct_o_multir  pct_hispanic  pct_no_vehicle  pct_lapop1_10  \
# 0      0.29          4.76          4.66           13.32           5.18
# 1      0.16          2.89          2.29            3.19          30.79
# 2      0.40          3.97          4.75            8.59          30.02
# 3      0.47          5.57          4.68            3.20          75.98
# 4      0.44          7.36          6.14            4.27          11.73
#
#    pct_lapop05_10  pct_lapop1_20  pct_lalowi1_10  pct_lalowi05_10  \
# 0           41.34           5.18            2.31            17.52
# 1           63.57          30.79            5.18            10.00
# 2           58.69          30.02            1.31            15.86
# 3           98.90          75.98           20.09            28.05
# 4           63.38          11.73            6.01            32.19
#
#    pct_lalowi1_20
# 0            2.31
# 1            5.18
# 2            1.31
# 3           20.09
# 4            6.01
#
# [5 rows x 168 columns]

# %%
# tn_food_access_df.to_csv('test_tn_access.csv')

# %%
# pct_ohu_snap_by_region = round((tn_food_access_df.groupby('region')['pct_ohu_snap'].mean()),2)

# %%
countries_and_regions_lowi = round((tn_food_access_df.groupby('county')['pct_LOWI'].mean()),2)
countries_and_regions_lowi.head()
# Out:
# county
# Anderson    36.04
# Bedford     41.59
# Benton      46.23
# Bledsoe     49.86
# Blount      31.18
# Name: pct_LOWI, dtype: float64

# %%
countries_and_regions_df['pct_LOWI'] = round((tn_food_access_df.groupby('county_and_state')['pct_LOWI'].mean()),2)
countries_and_regions_df.head()
# Out:
#      county_and_state   county region  pct_ohu_snap  pct_LOWI
# 0     Lake, Tennessee     Lake   West         36.79       NaN
# 1  Hancock, Tennessee  Hancock   East         28.69       NaN
# 2    Scott, Tennessee    Scott   East         28.64       NaN
# 3  Bledsoe, Tennessee  Bledsoe   East         27.56       NaN
# 4    Union, Tennessee    Union   East         26.32       NaN

# %%
tn_food_access_to_group = pd.read_csv('../data/tn_food_access_to_group.csv')

# %%
averaged_county_food_data = tn_food_access_to_group.groupby(['county','region']).mean().round(2)

# %%
median_county_food_data = tn_food_access_to_group.groupby(['county','region']).median().round(2)

# %%
averaged_county_food_data.reset_index()
# Out:
#         county  region  Urban  Pop2010  OHU2010  TractLOWI  TractKids  \
# 0     Anderson    East   0.47  4419.35  1838.41    1571.18     968.47
# 1      Bedford  Middle   0.33  5006.44  1836.67    2211.89    1341.00
# 2       Benton    West   0.20  3297.80  1412.60    1532.00     676.20
# 3      Bledsoe    East   0.00  4292.00  1565.67    2111.00     922.67
# 4       Blount    East   0.46  4393.21  1759.46    1391.39     977.71
# ..         ...     ...    ...      ...      ...        ...        ...
# 90       Wayne  Middle   0.00  4255.25  1534.00    1605.75     833.50
# 91     Weakley    West   0.36  3183.73  1263.45    1235.73     639.09
# 92       White  Middle   0.33  4306.83  1712.00    2196.83     967.50
# 93  Williamson  Middle   0.73  4950.86  1753.68     723.92    1449.43
# 94      Wilson  Middle   0.62  5428.24  2026.81    1361.29    1360.05
#
#     TractSeniors  TractWhite  TractBlack  ...  pct_o_multir  pct_hispanic  \
# 0         768.47     4062.65      167.47  ...          3.02          2.56
# 1         648.22     4094.22      396.00  ...          7.69          9.55
# 2         656.20     3147.40       64.20  ...          1.74          1.72
# 3         659.00     4016.00      156.67  ...          2.19          1.88
# 4         706.07     4106.89      120.71  ...          4.36          2.70
# ..           ...         ...         ...  ...           ...           ...
# 90        674.50     3928.00      244.50  ...          1.48          1.69
# 91        486.00     2829.45      248.73  ...          1.92          1.94
# 92        755.67     4123.17       76.50  ...          1.83          1.65
# 93        481.27     4425.08      214.62  ...          2.71          3.91
# 94        660.38     4827.57      347.48  ...          3.42          3.49
#
#     pct_no_vehicle  pct_lapop1_10  pct_lapop05_10  \
# 0             5.33          25.87           60.67
# 1             4.38          25.43           38.69
# 2             8.04          26.79           42.08
# 3             5.95           6.64            6.64
# 4             3.51          51.24           71.90
# ..             ...            ...             ...
# 90            5.38          24.40           24.40
# 91            7.69          36.16           46.20
# 92            4.66          29.03           34.36
# 93            2.42          60.67           88.18
# 94            4.04          49.80           71.92
#
#     pct_lapop1_203 - food_access_eda.ipynb  pct_lalowi1_10  pct_lalowi05_10  \
# 0                                    28.28            6.26            21.39
# 1                                    51.85            9.65            16.40
# 2                                    24.73           12.23            20.28
# 3                                      NaN            2.70             2.70
# 4                                    58.81           13.43            22.56
# ..                                     ...             ...              ...
# 90                                     NaN            9.27             9.27
# 91                                   47.70           15.68            21.44
# 92                                   76.76           16.91            19.66
# 93                                   60.67            6.36            10.34
# 94                                   57.43            8.78            16.79
#
#     pct_lalowi1_20  pct_lapop1_20
# 0             6.57          28.28
# 1            20.87          51.85
# 2            11.51          24.73
# 3              NaN            NaN
# 4            15.26          58.81
# ..             ...            ...
# 90             NaN            NaN
# 91           19.74          47.70
# 92           44.29          76.76
# 93            6.36          60.67
# 94           10.13          57.43
#
# [95 rows x 165 columns]

# %%
tn_food_access_df['lapop20share'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1489 entries, 0 to 1488
# Series name: lapop20share
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      float64
# dtypes: float64(1)
# memory usage: 11.8 KB

# %%
# averaged_county_food_data.to_csv('averaged_county_data.csv')

# %%
# median_county_food_data.to_csv('median_county_data.csv')

# %% [markdown]
# 3. Do more seniors or kids live in areas with low access to food? (Food Access Research Atlas)

# %%
# dataset_clean_eligibility = dataset_clean[dataset_clean["Program_Label"] == 'BDI-3 Eligibility Evaluation']
latracts_half_df = tn_food_access_df[tn_food_access_df['LATracts_half']==1]
latracts_1_df = tn_food_access_df[tn_food_access_df['LATracts1']==1]
latracts_10_df = tn_food_access_df[tn_food_access_df['LATracts10']==1]

# %%
round((latracts_half_df['pct_kids'].mean()),2)
# Out:
# 23.44

# %%
round((latracts_half_df['pct_seniors'].mean()),2)
# Out:
# 12.68

# %%
round((latracts_1_df['pct_kids'].mean()),2)
# Out:
# 23.81

# %%
round((latracts_1_df['pct_seniors'].mean()),2)
# Out:
# 13.14

# %%
round((latracts_10_df['pct_kids'].mean()),2)
# Out:
# 22.0

# %%
round((latracts_10_df['pct_seniors'].mean()),2)
# Out:
# 15.54

# %%
round((tn_food_access_df['pct_kids'].mean()),2)
# Out:
# 23.09

# %%
round((tn_food_access_df['pct_seniors'].mean()),2)
# Out:
# 13.66

# %% [markdown]
# So the tentative conclusion I'm drawing here: the percentage of kids and seniors in low access tracts isn't too different from the overall average.

# %% [markdown]
# 4. Are the counties with highest average percentages of SNAP enrollments per tract also the counties with the highest average percentages of food insecurity per tract? (Food Access Research Atlas)

# %%
pd.read_csv('../data/averaged_county_data_clean.csv')
# Out:
#         county       county_and_state  region  Urban  Pop2010  OHU2010  \
# 0     Anderson    Anderson, Tennessee    East   0.47  4419.35  1838.41
# 1      Bedford     Bedford, Tennessee  Middle   0.33  5006.44  1836.67
# 2       Benton      Benton, Tennessee    West   0.20  3297.80  1412.60
# 3      Bledsoe     Bledsoe, Tennessee    East   0.00  4292.00  1565.67
# 4       Blount      Blount, Tennessee    East   0.46  4393.21  1759.46
# ..         ...                    ...     ...    ...      ...      ...
# 90       Wayne       Wayne, Tennessee  Middle   0.00  4255.25  1534.00
# 91     Weakley     Weakley, Tennessee    West   0.36  3183.73  1263.45
# 92       White       White, Tennessee  Middle   0.33  4306.83  1712.00
# 93  Williamson  Williamson, Tennessee  Middle   0.73  4950.86  1753.68
# 94      Wilson      Wilson, Tennessee  Middle   0.62  5428.24  2026.81
#
#     TractLOWI  TractKids  TractSeniors  TractWhite  ...  pct_o_multir  \
# 0     1571.18     968.47        768.47     4062.65  ...          3.02
# 1     2211.89    1341.00        648.22     4094.22  ...          7.69
# 2     1532.00     676.20        656.20     3147.40  ...          1.74
# 3     2111.00     922.67        659.00     4016.00  ...          2.19
# 4     1391.39     977.71        706.07     4106.89  ...          4.36
# ..        ...        ...           ...         ...  ...           ...
# 90    1605.75     833.50        674.50     3928.00  ...          1.48
# 91    1235.73     639.09        486.00     2829.45  ...          1.92
# 92    2196.83     967.50        755.67     4123.17  ...          1.83
# 93     723.92    1449.43        481.27     4425.08  ...          2.71
# 94    1361.29    1360.05        660.38     4827.57  ...          3.42
#
#     pct_hispanic  pct_no_vehicle  pct_lapop1_10  pct_lapop05_10  \
# 0           2.56            5.33          25.87           60.67
# 1           9.55            4.38          25.43           38.69
# 2           1.72            8.04          26.79           42.08
# 3           1.88            5.95           6.64            6.64
# 4           2.70            3.51          51.24           71.90
# ..           ...             ...            ...             ...
# 90          1.69            5.38          24.40           24.40
# 91          1.94            7.69          36.16           46.20
# 92          1.65            4.66          29.03           34.36
# 93          3.91            2.42          60.67           88.18
# 94          3.49            4.04          49.80           71.92
#
#     pct_lapop1_20  pct_lalowi1_10  pct_lalowi05_10  pct_lalowi1_20  \
# 0           28.28            6.26            21.39            6.57
# 1           51.85            9.65            16.40           20.87
# 2           24.73           12.23            20.28           11.51
# 3             NaN            2.70             2.70             NaN
# 4           58.81           13.43            22.56           15.26
# ..            ...             ...              ...             ...
# 90            NaN            9.27             9.27             NaN
# 91          47.70           15.68            21.44           19.74
# 92          76.76           16.91            19.66           44.29
# 93          60.67            6.36            10.34            6.36
# 94          57.43            8.78            16.79           10.13
#
#     pct_lapop1_20.1
# 0             28.28
# 1             51.85
# 2             24.73
# 3               NaN
# 4             58.81
# ..              ...
# 90              NaN
# 91            47.70
# 92            76.76
# 93            60.67
# 94            57.43
#
# [95 rows x 140 columns]

# %%
# could probably accomplish this with a scatterplot
ax = sns.scatterplot(data=averaged_county_food_data, x='pct_ohu_snap', y='pct_no_vehicle', color="#06470c")
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
ax.patch.set_alpha(0.5)
# sns.set_palette("dark:#5A9_r")
plt.title('By County: OHU in SNAP and % Without Vehicle')
# Out:
# Text(0.5, 1.0, 'By County: OHU in SNAP and % Without Vehicle')

# %%
ax = sns.scatterplot(data=tn_food_access_df, x='pct_ohu_snap', y='pct_no_vehicle', color="#06470c")
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
ax.patch.set_alpha(0.5)
# sns.set_palette("dark:#5A9_r")
plt.title('SNAP Enrollment and Vehicle Access')
plt.ylabel('No Vehicle Access (%)')
plt.xlabel('OHU Enrolled in SNAP (%)')
# plt.savefig('ohu_snap_and_vehicle.png', transparent=True)
# Out:
# Text(0.5, 0, 'OHU Enrolled in SNAP (%)')

# %%
ax = sns.scatterplot(data=tn_food_access_df, x='pct_lalowi05_10', y='pct_no_vehicle', color="#721121")
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
ax.patch.set_alpha(0.5)
plt.title('Vehicle Access and Low Food Access/Low Income')
plt.xlabel('Low Income/Access at 1/2 and 10 Miles (%)')
plt.ylabel('No Vehicle Access (%)')
# plt.savefig('vehicle_lalowi05_10.png', transparent=True)
# Out:
# Text(0, 0.5, 'No Vehicle Access (%)')

# %%
ax = sns.scatterplot(data=tn_food_access_df, x='pct_lalowi1_10', y='pct_no_vehicle', color="#721121")
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
ax.patch.set_alpha(0.5)
plt.title('No Vehicle and Low Food Access at 1 and 10 Miles')
plt.xlabel('Low Income/Access at 1 and 10 Miles (%)')
plt.ylabel('Population Without Vehicle Access (%)')
# plt.savefig('low_access_1_10.png', transparent=True)
# Out:
# Text(0, 0.5, 'Population Without Vehicle Access (%)')

# %%
# food_dict = {'pct_lapop1_10':"#0343df"}

# %%
sns.scatterplot(data=averaged_county_food_data, x='pct_ohu_snap', y='pct_lapop1_10', color='#380835')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
plt.title('By County: Avg OHU SNAP and % LA Population at 1/10 Miles')
# sns.set_palette("dark:#5A9_r")
# Out:
# Text(0.5, 1.0, 'By County: Avg OHU SNAP and % LA Population at 1/10 Miles')

# %%
sns.scatterplot(data=tn_food_access_df, x='pct_ohu_snap', y='pct_lapop1_10', color='#380835')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
plt.title('Low Access at 1 and 10 Miles')
plt.xlabel('OHU Enrolled in SNAP (%)')
plt.ylabel('Low Access at 1 and 10 Miles (%)')
# plt.savefig('low_access_1_10.png', transparent=True)
# sns.set_palette("dark:#5A9_r")
# Out:
# Text(0, 0.5, 'Low Access at 1 and 10 Miles (%)')

# %%
sns.scatterplot(data=tn_food_access_df, x='pct_ohu_snap', y='pct_lapop05_10', color='#380835')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
plt.title('Low Access at 1/2 and 10 Miles')
plt.xlabel('OHU Enrolled in SNAP (%)')
plt.ylabel('Low Access at 1/2 and 10 Miles (%)')
# plt.savefig('low_access_05_10.png', transparent=True)
# sns.set_palette("dark:#5A9_r")
# Out:
# Text(0, 0.5, 'Low Access at 1/2 and 10 Miles (%)')

# %%
sns.scatterplot(data=averaged_county_food_data, x='pct_ohu_snap', y='pct_lalowi1_10', color='blue')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
plt.title('Low Access/Income at 1 and 10 Miles')
plt.xlabel('OHU Enrolled in SNAP (%)')
plt.ylabel('Low Access/Income at 1 and 10 Miles (%)')
# sns.set_palette("dark:#5A9_r")
# Out:
# Text(0, 0.5, 'Low Access/Income at 1 and 10 Miles (%)')

# %%
sns.scatterplot(data=tn_food_access_df, x='pct_ohu_snap', y='pct_lalowi1_10', color='blue')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
plt.title('Low Access/Income at 1 and 10 Miles')
plt.xlabel('OHU Enrolled in SNAP (%)')
plt.ylabel('Low Access/Income at 1 and 10 Miles (%)')
# plt.savefig('lalowi1_10.png', transparent=True)
# sns.set_palette("Dark2")
# Out:
# Text(0, 0.5, 'Low Access/Income at 1 and 10 Miles (%)')

# %%
sns.scatterplot(data=tn_food_access_df, x='pct_ohu_snap', y='pct_lalowi05_10', color='blue')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
plt.title('Low Access/Income at 1/2 and 10 Miles')
plt.xlabel('OHU Enrolled in SNAP (%)')
plt.ylabel('Low Access/Income at 1/2 and 10 Miles (%)')
# plt.savefig('lalowi05_10.png', transparent=True)
# sns.set_palette("Dark2")
# Out:
# Text(0, 0.5, 'Low Access/Income at 1/2 and 10 Miles (%)')

# %%
sns.scatterplot(data=tn_food_access_df, y='MedianFamilyIncome', x='pct_lalowi05_10', color='darkolivegreen')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
plt.title('Median Income and Low Access/Income')
plt.xlabel('Low Access/Income at 1/2 and 10 Miles (%)')
plt.ylabel('Median Family Income')
plt.yticks([50000,100000,150000,200000],['$50k','$10k','$150k','$200k'])
# plt.savefig('income_access05_10.png',transparent=True)
# sns.set_palette("Dark2")
# Out:
# ([<matplotlib.axis.YTick at 0x2548158fe90>,
#   <matplotlib.axis.YTick at 0x254815ac190>,
#   <matplotlib.axis.YTick at 0x254815ceb90>,
#   <matplotlib.axis.YTick at 0x254815ecb90>],
#  [Text(0, 50000, '$50k'),
#   Text(0, 100000, '$10k'),
#   Text(0, 150000, '$150k'),
#   Text(0, 200000, '$200k')])

# %%
sns.scatterplot(data=tn_food_access_df, y='MedianFamilyIncome', x='pct_lapop05_10', color='darkolivegreen')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})
plt.title('Median Income and Low Access')
plt.xlabel('Low Access at 1/2 and 10 Miles (%)')
plt.ylabel('Median Family Income')
plt.yticks([50000,100000,150000,200000],['$50k','$10k','$150k','$200k'])
# plt.savefig('all_income_low access.png', transparent=True)
# sns.set_palette("Dark2")
# Out:
# ([<matplotlib.axis.YTick at 0x2548161f550>,
#   <matplotlib.axis.YTick at 0x254815fd790>,
#   <matplotlib.axis.YTick at 0x254815fb4d0>,
#   <matplotlib.axis.YTick at 0x2548165da10>],
#  [Text(0, 50000, '$50k'),
#   Text(0, 100000, '$10k'),
#   Text(0, 150000, '$150k'),
#   Text(0, 200000, '$200k')])

# %%
sns.scatterplot(data=tn_food_access_df, x='lablack10share', y='MedianFamilyIncome')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})

# %%
sns.scatterplot(data=tn_food_access_df, x='lakids1share', y='MedianFamilyIncome', color='darkolivegreen')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})

# %%
sns.scatterplot(data=tn_food_access_df, x='lakids10share', y='MedianFamilyIncome', color='darkolivegreen')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})

# %%
sns.scatterplot(data=tn_food_access_df, x='lakids10share', y='Pop2010', color='#fd5956')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})

# %%
sns.scatterplot(data=averaged_county_food_data, x='lakids10share', y='Pop2010', color='#fd5956')
sns.set_style("darkgrid", {"grid.color": "lightsteelblue", "grid.linestyle": ":"})

# %%
# tn_food_access_df.to_csv('tn_food_access_df_lv22424.csv')

# %% [markdown]
# low access itself may have no correlation or in some cases a weak positive correlation with income or population. my thought here is that Tennessee is a low access state. It would be interesting to clean and pull in the full dataset for food access and compare.

# %% [markdown]
# idea: correlation btn low access on its own and low access/low income tracts

# %% [markdown]
# 5. Which counties have the highest/lowest disparities in low income and low food access among census tracts? Of those counties, how do the min/max food insecure tract demographics compare? (Food Access Research Atlas)

# %%
tn_food_access_df.head()
# Out:
#        ct_long    county     county_and_state region      state  \
# 0  47001020100  Anderson  Anderson, Tennessee   East  Tennessee
# 1  47001020201  Anderson  Anderson, Tennessee   East  Tennessee
# 2  47001020202  Anderson  Anderson, Tennessee   East  Tennessee
# 3  47001020300  Anderson  Anderson, Tennessee   East  Tennessee
# 4  47001020400  Anderson  Anderson, Tennessee   East  Tennessee
#
#                     country  Urban  Pop2010  OHU2010  TractLOWI  ...  \
# 0  United States of America      1     3111     1546       1381  ...
# 1  United States of America      1     3670     1535        604  ...
# 2  United States of America      1     4507     2025       1741  ...
# 3  United States of America      1     3822     1656       1077  ...
# 4  United States of America      1     4508     2013       1995  ...
#
#    pct_aian  pct_o_multir  pct_hispanic  pct_no_vehicle  pct_lapop1_10  \
# 0      0.29          4.76          4.66           13.32           5.18
# 1      0.16          2.89          2.29            3.19          30.79
# 2      0.40          3.97          4.75            8.59          30.02
# 3      0.47          5.57          4.68            3.20          75.98
# 4      0.44          7.36          6.14            4.27          11.73
#
#    pct_lapop05_10  pct_lapop1_20  pct_lalowi1_10  pct_lalowi05_10  \
# 0           41.34           5.18            2.31            17.52
# 1           63.57          30.79            5.18            10.00
# 2           58.69          30.02            1.31            15.86
# 3           98.90          75.98           20.09            28.05
# 4           63.38          11.73            6.01            32.19
#
#    pct_lalowi1_20
# 0            2.31
# 1            5.18
# 2            1.31
# 3           20.09
# 4            6.01
#
# [5 rows x 168 columns]

# %%
# df.groupby('group_var')['values_var'].describe()

pct_lapop_1_10_describe_county = tn_food_access_df.groupby('county_and_state')['pct_lapop1_10'].describe()

# %%
pct_lapop_1_10_description_by_county_df = pd.DataFrame(pct_lapop_1_10_describe_county).reset_index()

# %%
pct_lapop_1_10_description_by_county_df.head()
# Out:
#       county_and_state  count       mean        std   min     25%     50%  \
# 0  Anderson, Tennessee    9.0  25.874444  26.003028  3.05   6.650  11.730
# 1   Bedford, Tennessee    7.0  25.427143  26.548700  0.67   1.250  19.280
# 2    Benton, Tennessee    3.0  26.793333  27.882318  0.00  12.365  24.730
# 3   Bledsoe, Tennessee    2.0   6.640000   5.529575  2.73   4.685   6.640
# 4    Blount, Tennessee   14.0  51.240000  43.333683  0.00   8.060  56.875
#
#       75%     max
# 0  30.790   75.98
# 1  48.000   59.54
# 2  40.190   55.65
# 3   8.595   10.55
# 4  93.570  100.00

# %%
sns.histplot(data=pct_lapop_1_10_description_by_county_df, x='std', bins=25, color='#380835')
# Out:
# <Axes: xlabel='std', ylabel='Count'>

# %%
pct_lalowi1_10_describe_county_state = tn_food_access_df.groupby('county_and_state')['pct_lalowi1_10'].describe()

# %%
pct_lalowi1_10_description_by_county_state_df = pd.DataFrame(pct_lalowi1_10_describe_county_state).reset_index()

# %%
pct_lalowi1_10_description_by_county_state_df.head()
# Out:
#       county_and_state  count       mean        std   min     25%     50%  \
# 0  Anderson, Tennessee    9.0   6.256667   5.880468  1.31  2.3100   5.180
# 1   Bedford, Tennessee    7.0   9.648571  10.697907  0.25  0.5650   3.540
# 2    Benton, Tennessee    3.0  12.233333  12.610568  0.00  5.7550  11.510
# 3   Bledsoe, Tennessee    2.0   2.695000   2.255671  1.10  1.8975   2.695
# 4    Blount, Tennessee   14.0  13.427143  14.805989  0.00  1.6600   5.985
#
#        75%    max
# 0   6.3400  20.09
# 1  19.8100  23.00
# 2  18.3500  25.19
# 3   3.4925   4.29
# 4  21.0875  46.96

# %%
sns.histplot(data=pct_lalowi1_10_description_by_county_state_df, x='std', bins=25, color='blue')
# plt.savefig('lalowi110bycounty.png',transparent=True)
# Out:
# <Axes: xlabel='std', ylabel='Count'>

# %%
highest_lalowi1_10_std_by_county_state = pct_lalowi1_10_description_by_county_state_df.sort_values(by='std', ascending=False)

# %%
top_ten_lalowi1_10_counties_state = highest_lalowi1_10_std_by_county_state.head(10)

# %%
top_ten_lalowi1_10_counties_state_df = pd.DataFrame(top_ten_lalowi1_10_counties_state).reset_index()

# %% [markdown]
# I truly don't think anyone's going to care about this barplot lol
# I need to find another way

# %%
sns.barplot(top_ten_lalowi1_10_counties_state, y='county_and_state', x='std', color='blue')
# plt.savefig('top_ten_std_lalowi1_10_2.png', transparent=True)
# Out:
# <Axes: xlabel='std', ylabel='county_and_state'>

# %%
# and that is not how you make a heat map! leaving this here for later research
# sns.heatmap(data=pct_lalowi1_10_description_by_county_df)

# %%
tn_food_access_df = pd.read_csv('../data/tn_food_access_df_lv22424.csv')

# %%
tn_food_access_df.head()
# Out:
#        ct_long    county     county_and_state region      state  \
# 0  47001020100  Anderson  Anderson, Tennessee   East  Tennessee
# 1  47001020201  Anderson  Anderson, Tennessee   East  Tennessee
# 2  47001020202  Anderson  Anderson, Tennessee   East  Tennessee
# 3  47001020300  Anderson  Anderson, Tennessee   East  Tennessee
# 4  47001020400  Anderson  Anderson, Tennessee   East  Tennessee
#
#                     country  Urban  Pop2010  OHU2010  TractLOWI  ...  \
# 0  United States of America      1     3111     1546       1381  ...
# 1  United States of America      1     3670     1535        604  ...
# 2  United States of America      1     4507     2025       1741  ...
# 3  United States of America      1     3822     1656       1077  ...
# 4  United States of America      1     4508     2013       1995  ...
#
#    pct_aian  pct_o_multir  pct_hispanic  pct_no_vehicle  pct_lapop1_10  \
# 0      0.29          4.76          4.66           13.32           5.18
# 1      0.16          2.89          2.29            3.19          30.79
# 2      0.40          3.97          4.75            8.59          30.02
# 3      0.47          5.57          4.68            3.20          75.98
# 4      0.44          7.36          6.14            4.27          11.73
#
#    pct_lapop05_10  pct_lapop1_20  pct_lalowi1_10  pct_lalowi05_10  \
# 0           41.34           5.18            2.31            17.52
# 1           63.57          30.79            5.18            10.00
# 2           58.69          30.02            1.31            15.86
# 3           98.90          75.98           20.09            28.05
# 4           63.38          11.73            6.01            32.19
#
#    pct_lalowi1_20
# 0            2.31
# 1            5.18
# 2            1.31
# 3           20.09
# 4            6.01
#
# [5 rows x 168 columns]

# %%
# cols_to_plot = ['Pop2010', 'pct_ohu_snap','pct_LOWI','pct_no_vehicle','MedianFamilyIncome','pct_lapop1_10','pct_lapop05_10', 'pct_lapop1_20','pct_lalowi1_10', 'pct_lalowi05_10', 'pct_lalowi1_20']
# sns.pairplot(tn_food_access_df[cols_to_plot])

# %%
# cols_to_plot_2 = ['Pop2010', 'pct_ohu_snap','MedianFamilyIncome','pct_lapop1_10','pct_lalowi1_10','pct_LOWI', 'pct_kids','pct_seniors','pct_white','pct_black','pct_asian','pct_pac_isl','pct_aian','pct_o_multir','pct_hispanic','pct_no_vehicle']
# sns.pairplot(tn_food_access_df[cols_to_plot_2])

# %% [markdown]
# https://www.statology.org/deciles-in-python/
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2652960/#:~:text=A%20simple%20but%20effective%20way,used%20by%20Gold%20et%20al
#
# https://www.cdc.gov/nchs/data/series/sr_02/sr02_141.pdf
#
# https://ourworldindata.org/what-is-the-gini-coefficient

# %% [markdown]
# To show the demographics of the top standard deviation counties, a dashboard might be the best route.

# %%
# 'pct_LOWI', 'pct_kids','pct_seniors','pct_white','pct_black','pct_asian','pct_pac_isl','pct_aian','pct_o_multir','pct_hispanic','pct_no_vehicle'
