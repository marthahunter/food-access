# %% [markdown]
# Importing packages

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Importing food access dataset

# %%
food_access_df = pd.read_csv('../data/food_access.csv')

# %% [markdown]
# Checking head/info

# %% [markdown]
# // TO DO: Isolate just the TN data from `food_access_df` and read into a new dataframe.

# %%
food_access_df.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0      0.00                  0  ...
# 1                  0     181.0      8.34                  1  ...
# 2                  0       0.0      0.00                  0  ...
# 3                  0       0.0      0.00                  0  ...
# 4                  0     181.0      1.68                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# 1         214.0       888.0      1217.0         5.0         0.0        5.0
# 2         439.0      2576.0       647.0        17.0         5.0       11.0
# 3         904.0      4086.0       193.0        18.0         4.0       11.0
# 4        1126.0      8666.0      1437.0       296.0         9.0       48.0
#
#    TractOMultir  TractHispanic  TractHUNV  TractSNAP
# 0          45.0           44.0        6.0      102.0
# 1          55.0           75.0       89.0      156.0
# 2         117.0           87.0       99.0      172.0
# 3          74.0           85.0       21.0       98.0
# 4         310.0          355.0      230.0      339.0
#
# [5 rows x 147 columns]

# %% [markdown]
# Filtering `food_access_df` into new DataFrame with just the TN entries.

# %%
tn_food_access_df = food_access_df[food_access_df['State']=='Tennessee']

# %%
tn_food_access_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1489 entries, 59698 to 61186
# Columns: 147 entries, CensusTract to TractSNAP
# dtypes: float64(126), int64(19), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# Attempting to edit the `CensusTract` column to match Census tract numbers from `census_income_df`

# %% [markdown]
# First checking dtypes and then creating a new `CensusTract_Formatted` column, converting the int64 dtype in `CensusTract` into an object/string.

# %%
tn_food_access_df.dtypes
# Out:
# CensusTract        int64
# State             object
# County            object
# Urban              int64
# Pop2010            int64
#                   ...
# TractAIAN        float64
# TractOMultir     float64
# TractHispanic    float64
# TractHUNV        float64
# TractSNAP        float64
# Length: 147, dtype: object

# %%
tn_food_access_df['CensusTract_Formatted'] = tn_food_access_df['CensusTract'].astype(str)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_20948\3094399602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn_food_access_df['CensusTract_Formatted'] = tn_food_access_df['CensusTract'].astype(str)

# %%
# d['Report Number'] = d['Report Number'].str[3:]
tn_food_access_df['CensusTract_Formatted2'] = tn_food_access_df['CensusTract_Formatted'].str[6:]
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_20948\551598922.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn_food_access_df['CensusTract_Formatted2'] = tn_food_access_df['CensusTract_Formatted'].str[6:]

# %% [markdown]
# Creating a new column each time just in case my methods don't work, but also going back to delete unneeded columns. Will rename to `CensusTract_Formatted` once I get the column I need.

# %%
del tn_food_access_df['CensusTract_Formatted']

# %% [markdown]
# I probably need to use a lambda argument to insert the decimal point into the existing numbers. This is from Free Code Camp:
#
# lambda argument(s) : expression
#
#
# 1. lambda is a keyword in Python for defining the anonymous function.
# 2. argument(s) is a placeholder, that is a variable that will be used to hold the value you want to pass into the function expression. A lambda function can have multiple variables depending on what you want to achieve.
# 3. expression is the code you want to execute in the lambda function.
#
# https://www.freecodecamp.org/news/python-lambda-function-explained/

# %%
tn_food_access_df['CensusTract_Formatted3'] = tn_food_access_df['CensusTract_Formatted2'].apply(lambda x: x[:3] + '.' + x[3:])
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_20948\1897836778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn_food_access_df['CensusTract_Formatted3'] = tn_food_access_df['CensusTract_Formatted2'].apply(lambda x: x[:3] + '.' + x[3:])

# %% [markdown]
# Amazing! I can delete the extra CT formatted column and rename #3 to the most current.

# %%
del tn_food_access_df['CensusTract_Formatted2']

# %%
# rename column 'A' to 'X'
# df = df.rename(columns={'A': 'X'})

tn_food_access_df = tn_food_access_df.rename(columns={'CensusTract':'CT_Old','CensusTract_Formatted3':'CT_Clean'})

# %%
tn_food_access_df.head()
# Out:
#             CT_Old      State           County  Urban  Pop2010  OHU2010  \
# 59698  47001020100  Tennessee  Anderson County      1     3111     1546
# 59699  47001020201  Tennessee  Anderson County      1     3670     1535
# 59700  47001020202  Tennessee  Anderson County      1     4507     2025
# 59701  47001020300  Tennessee  Anderson County      1     3822     1656
# 59702  47001020400  Tennessee  Anderson County      1     4508     2013
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 59698                  0       6.0      0.19                  0  ...
# 59699                  0     103.0      2.81                  0  ...
# 59700                  0     230.0      5.10                  0  ...
# 59701                  0       0.0      0.00                  0  ...
# 59702                  0     106.0      2.35                  1  ...
#
#        TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 59698      1969.0       853.0       130.0         2.0        9.0
# 59699      3158.0       144.0       256.0         0.0        6.0
# 59700      3988.0       194.0       128.0         0.0       18.0
# 59701      3290.0       278.0        20.0         3.0       18.0
# 59702      3855.0       264.0        34.0         3.0       20.0
#
#        TractOMultir  TractHispanic  TractHUNV  TractSNAP  CT_Clean
# 59698         148.0          145.0      206.0      438.0    201.00
# 59699         106.0           84.0       49.0       31.0    202.01
# 59700         179.0          214.0      174.0      208.0    202.02
# 59701         213.0          179.0       53.0      109.0    203.00
# 59702         332.0          277.0       86.0      406.0    204.00
#
# [5 rows x 148 columns]

# %% [markdown]
# Reading in Census dataset and checking head/info. This will need to be cleaned and transformed!

# %%
census_income_df = pd.read_excel('../data/census_tn_income_b19001.xlsx')

# %%
census_income_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Columns: 3405 entries, Unnamed: 0 to Unnamed: 3404
# dtypes: object(3405)
# memory usage: 479.0+ KB

# %%
census_income_df.head()
# Out:
#            Unnamed: 0 Tennessee Unnamed: 2 Census Tract 201, Anderson, TN  \
# 0                 NaN     Value      Error                          Value
# 1              Total:   2713635       7405                           1531
# 2   Less than $10,000    144639       2807                            156
# 3  $10,000 to $14,999    122212       3595                             74
# 4  $15,000 to $19,999    111419       2673                             41
#
#   Unnamed: 4 Census Tract 202.01, Anderson, TN Unnamed: 6  \
# 0      Error                             Value      Error
# 1        225                              2029        160
# 2         90                                93         73
# 3         52                                28         35
# 4         42                                26         30
#
#   Census Tract 202.02, Anderson, TN Unnamed: 8 Census Tract 203, Anderson, TN  \
# 0                             Value      Error                          Value
# 1                              1951        235                           1567
# 2                               235        127                             25
# 3                               159        126                             95
# 4                                 7         13                             56
#
#    ... Census Tract 309.05, Wilson, TN Unnamed: 3396  \
# 0  ...                           Value         Error
# 1  ...                            1925           288
# 2  ...                              38            64
# 3  ...                               0            19
# 4  ...                               0            19
#
#   Census Tract 309.06, Wilson, TN Unnamed: 3398  \
# 0                           Value         Error
# 1                            1963           244
# 2                               0            19
# 3                              21            35
# 4                              17            30
#
#   Census Tract 309.07, Wilson, TN Unnamed: 3400  \
# 0                           Value         Error
# 1                            2513           276
# 2                             109            89
# 3                              60            58
# 4                              59            68
#
#   Census Tract 309.08, Wilson, TN Unnamed: 3402 Census Tract 310, Wilson, TN  \
# 0                           Value         Error                        Value
# 1                            3124           432                         2365
# 2                             133            92                          159
# 3                              61           102                          174
# 4                              46            52                          124
#
#   Unnamed: 3404
# 0         Error
# 1           373
# 2           106
# 3           158
# 4            75
#
# [5 rows x 3405 columns]

# %% [markdown]
# Renaming the first column so it doesn't get dropped with the rest of the 'unnamed' columns.

# %%
census_income_df = census_income_df.rename(columns={'Unnamed: 0':'census_tract'}) # census_tract will the the right label once the data is transposed
census_income_df.head()
# Out:
#          census_tract Tennessee Unnamed: 2 Census Tract 201, Anderson, TN  \
# 0                 NaN     Value      Error                          Value
# 1              Total:   2713635       7405                           1531
# 2   Less than $10,000    144639       2807                            156
# 3  $10,000 to $14,999    122212       3595                             74
# 4  $15,000 to $19,999    111419       2673                             41
#
#   Unnamed: 4 Census Tract 202.01, Anderson, TN Unnamed: 6  \
# 0      Error                             Value      Error
# 1        225                              2029        160
# 2         90                                93         73
# 3         52                                28         35
# 4         42                                26         30
#
#   Census Tract 202.02, Anderson, TN Unnamed: 8 Census Tract 203, Anderson, TN  \
# 0                             Value      Error                          Value
# 1                              1951        235                           1567
# 2                               235        127                             25
# 3                               159        126                             95
# 4                                 7         13                             56
#
#    ... Census Tract 309.05, Wilson, TN Unnamed: 3396  \
# 0  ...                           Value         Error
# 1  ...                            1925           288
# 2  ...                              38            64
# 3  ...                               0            19
# 4  ...                               0            19
#
#   Census Tract 309.06, Wilson, TN Unnamed: 3398  \
# 0                           Value         Error
# 1                            1963           244
# 2                               0            19
# 3                              21            35
# 4                              17            30
#
#   Census Tract 309.07, Wilson, TN Unnamed: 3400  \
# 0                           Value         Error
# 1                            2513           276
# 2                             109            89
# 3                              60            58
# 4                              59            68
#
#   Census Tract 309.08, Wilson, TN Unnamed: 3402 Census Tract 310, Wilson, TN  \
# 0                           Value         Error                        Value
# 1                            3124           432                         2365
# 2                             133            92                          159
# 3                              61           102                          174
# 4                              46            52                          124
#
#   Unnamed: 3404
# 0         Error
# 1           373
# 2           106
# 3           158
# 4            75
#
# [5 rows x 3405 columns]

# %% [markdown]
# Now dropping the `error` columns. I can go back and look at these later, but for now, just the values will do.

# %%
census_income_df_cleaner = census_income_df[census_income_df.columns.drop(list(census_income_df.filter(regex='Unnamed')))]

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.transpose.html
# https://stackoverflow.com/questions/38148877/how-to-remove-the-extra-row-or-column-after-transpose-in-pandas
census_income_df_cleaner = census_income_df_cleaner.set_index('census_tract').transpose()
census_income_df_cleaner.head()
# Out:
# census_tract                         NaN   Total: Less than $10,000  \
# Tennessee                          Value  2713635            144639
# Census Tract 201, Anderson, TN     Value     1531               156
# Census Tract 202.01, Anderson, TN  Value     2029                93
# Census Tract 202.02, Anderson, TN  Value     1951               235
# Census Tract 203, Anderson, TN     Value     1567                25
#
# census_tract                      $10,000 to $14,999 $15,000 to $19,999  \
# Tennessee                                     122212             111419
# Census Tract 201, Anderson, TN                    74                 41
# Census Tract 202.01, Anderson, TN                 28                 26
# Census Tract 202.02, Anderson, TN                159                  7
# Census Tract 203, Anderson, TN                    95                 56
#
# census_tract                      $20,000 to $24,999 $25,000 to $29,999  \
# Tennessee                                     115858             114639
# Census Tract 201, Anderson, TN                    50                106
# Census Tract 202.01, Anderson, TN                 74                 24
# Census Tract 202.02, Anderson, TN                 13                101
# Census Tract 203, Anderson, TN                    30                 84
#
# census_tract                      $30,000 to $34,999 $35,000 to $39,999  \
# Tennessee                                     115755             118563
# Census Tract 201, Anderson, TN                    31                262
# Census Tract 202.01, Anderson, TN                  0                 54
# Census Tract 202.02, Anderson, TN                 48                 40
# Census Tract 203, Anderson, TN                    65                 74
#
# census_tract                      $40,000 to $44,999 $45,000 to $49,999  \
# Tennessee                                     112751             114744
# Census Tract 201, Anderson, TN                   154                 52
# Census Tract 202.01, Anderson, TN                 89                 86
# Census Tract 202.02, Anderson, TN                 33                140
# Census Tract 203, Anderson, TN                    46                 53
#
# census_tract                      $50,000 to $59,999 $60,000 to $74,999  \
# Tennessee                                     211329             267360
# Census Tract 201, Anderson, TN                   168                138
# Census Tract 202.01, Anderson, TN                151                219
# Census Tract 202.02, Anderson, TN                 74                257
# Census Tract 203, Anderson, TN                   173                170
#
# census_tract                      $75,000 to $99,999 $100,000 to $124,999  \
# Tennessee                                     357378               257232
# Census Tract 201, Anderson, TN                   101                  125
# Census Tract 202.01, Anderson, TN                124                  242
# Census Tract 202.02, Anderson, TN                164                  134
# Census Tract 203, Anderson, TN                   280                  174
#
# census_tract                      $125,000 to $149,999 $150,000 to $199,999  \
# Tennessee                                       169567               182209
# Census Tract 201, Anderson, TN                      16                   46
# Census Tract 202.01, Anderson, TN                  195                  256
# Census Tract 202.02, Anderson, TN                  129                  295
# Census Tract 203, Anderson, TN                     106                   93
#
# census_tract                      $200,000 or more
# Tennessee                                   197980
# Census Tract 201, Anderson, TN                  11
# Census Tract 202.01, Anderson, TN              368
# Census Tract 202.02, Anderson, TN              122
# Census Tract 203, Anderson, TN                  43

# %%
# Use DataFrame.columns.values.tolist() to retrieve a list of columns from the DataFrame header.
# https://www.boardinfinity.com/blog/how-to-get-column-names-in-pandas
census_income_df_cleaner.columns.values.tolist()
# Out:
# [nan,
#  'Total:',
#  'Less than $10,000',
#  '$10,000 to $14,999',
#  '$15,000 to $19,999',
#  '$20,000 to $24,999',
#  '$25,000 to $29,999',
#  '$30,000 to $34,999',
#  '$35,000 to $39,999',
#  '$40,000 to $44,999',
#  '$45,000 to $49,999',
#  '$50,000 to $59,999',
#  '$60,000 to $74,999',
#  '$75,000 to $99,999',
#  '$100,000 to $124,999',
#  '$125,000 to $149,999',
#  '$150,000 to $199,999',
#  '$200,000 or more']
