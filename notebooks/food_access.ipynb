# %% [markdown]
# Importing packages

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Importing food access dataset

# %%
food_access_df = pd.read_csv('../data/food_access.csv')

# %% [markdown]
# Checking head/info

# %%
food_access_df.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0      0.00                  0  ...
# 1                  0     181.0      8.34                  1  ...
# 2                  0       0.0      0.00                  0  ...
# 3                  0       0.0      0.00                  0  ...
# 4                  0     181.0      1.68                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# 1         214.0       888.0      1217.0         5.0         0.0        5.0
# 2         439.0      2576.0       647.0        17.0         5.0       11.0
# 3         904.0      4086.0       193.0        18.0         4.0       11.0
# 4        1126.0      8666.0      1437.0       296.0         9.0       48.0
#
#    TractOMultir  TractHispanic  TractHUNV  TractSNAP
# 0          45.0           44.0        6.0      102.0
# 1          55.0           75.0       89.0      156.0
# 2         117.0           87.0       99.0      172.0
# 3          74.0           85.0       21.0       98.0
# 4         310.0          355.0      230.0      339.0
#
# [5 rows x 147 columns]

# %%
food_access_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72531 entries, 0 to 72530
# Columns: 147 entries, CensusTract to TractSNAP
# dtypes: float64(126), int64(19), object(2)
# memory usage: 81.3+ MB

# %% [markdown]
# Reading in Census dataset and checking head/info. This will need to be cleaned and transformed!

# %%
census_income_df = pd.read_excel('../data/census_tn_income_b19001.xlsx')

# %%
census_income_df.head()
# Out:
#                B19001  \
# 0                 NaN
# 1                 NaN
# 2              Total:
# 3   Less than $10,000
# 4  $10,000 to $14,999
#
#   Household Income in the Past 12 Months (In 2022 Inflation-adjusted Dollars)  \
# 0                                          Tennessee
# 1                                              Value
# 2                                            2713635
# 3                                             144639
# 4                                             122212
#
#   Unnamed: 2                      Unnamed: 3 Unnamed: 4  \
# 0        NaN  Census Tract 201, Anderson, TN        NaN
# 1      Error                           Value      Error
# 2       7405                            1531        225
# 3       2807                             156         90
# 4       3595                              74         52
#
#                           Unnamed: 5 Unnamed: 6  \
# 0  Census Tract 202.01, Anderson, TN        NaN
# 1                              Value      Error
# 2                               2029        160
# 3                                 93         73
# 4                                 28         35
#
#                           Unnamed: 7 Unnamed: 8  \
# 0  Census Tract 202.02, Anderson, TN        NaN
# 1                              Value      Error
# 2                               1951        235
# 3                                235        127
# 4                                159        126
#
#                        Unnamed: 9  ...                    Unnamed: 3395  \
# 0  Census Tract 203, Anderson, TN  ...  Census Tract 309.05, Wilson, TN
# 1                           Value  ...                            Value
# 2                            1567  ...                             1925
# 3                              25  ...                               38
# 4                              95  ...                                0
#
#   Unnamed: 3396                    Unnamed: 3397 Unnamed: 3398  \
# 0           NaN  Census Tract 309.06, Wilson, TN           NaN
# 1         Error                            Value         Error
# 2           288                             1963           244
# 3            64                                0            19
# 4            19                               21            35
#
#                      Unnamed: 3399 Unnamed: 3400  \
# 0  Census Tract 309.07, Wilson, TN           NaN
# 1                            Value         Error
# 2                             2513           276
# 3                              109            89
# 4                               60            58
#
#                      Unnamed: 3401 Unnamed: 3402  \
# 0  Census Tract 309.08, Wilson, TN           NaN
# 1                            Value         Error
# 2                             3124           432
# 3                              133            92
# 4                               61           102
#
#                   Unnamed: 3403 Unnamed: 3404
# 0  Census Tract 310, Wilson, TN           NaN
# 1                         Value         Error
# 2                          2365           373
# 3                           159           106
# 4                           174           158
#
# [5 rows x 3405 columns]

# %%
census_income_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Columns: 3405 entries, B19001 to Unnamed: 3404
# dtypes: object(3405)
# memory usage: 505.6+ KB
