# %% [markdown]
# Importing packages

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Importing food access dataset

# %%
food_access_df = pd.read_csv('../data/food_access.csv')

# %% [markdown]
# Checking head/info

# %% [markdown]
# // TO DO: Isolate just the TN data from `food_access_df` and read into a new dataframe.

# %%
food_access_df.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0      0.00                  0  ...
# 1                  0     181.0      8.34                  1  ...
# 2                  0       0.0      0.00                  0  ...
# 3                  0       0.0      0.00                  0  ...
# 4                  0     181.0      1.68                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# 1         214.0       888.0      1217.0         5.0         0.0        5.0
# 2         439.0      2576.0       647.0        17.0         5.0       11.0
# 3         904.0      4086.0       193.0        18.0         4.0       11.0
# 4        1126.0      8666.0      1437.0       296.0         9.0       48.0
#
#    TractOMultir  TractHispanic  TractHUNV  TractSNAP
# 0          45.0           44.0        6.0      102.0
# 1          55.0           75.0       89.0      156.0
# 2         117.0           87.0       99.0      172.0
# 3          74.0           85.0       21.0       98.0
# 4         310.0          355.0      230.0      339.0
#
# [5 rows x 147 columns]

# %% [markdown]
# Filtering `food_access_df` into new DataFrame with just the TN entries.

# %%
tn_food_access_df = food_access_df[food_access_df['State']=='Tennessee']

# %%
tn_food_access_df_clean =

# %%
tn_food_access_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1489 entries, 59698 to 61186
# Columns: 147 entries, CensusTract to TractSNAP
# dtypes: float64(126), int64(19), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# Reading in Census dataset and checking head/info. This will need to be cleaned and transformed!

# %%
census_income_df = pd.read_excel('../data/census_tn_income_b19001.xlsx')

# %%
census_income_df.head(25)
# Out:
#               Unnamed: 0 Tennessee Unnamed: 2 Census Tract 201, Anderson, TN  \
# 0                    NaN     Value      Error                          Value
# 1                 Total:   2713635       7405                           1531
# 2      Less than $10,000    144639       2807                            156
# 3     $10,000 to $14,999    122212       3595                             74
# 4     $15,000 to $19,999    111419       2673                             41
# 5     $20,000 to $24,999    115858       2949                             50
# 6     $25,000 to $29,999    114639       2827                            106
# 7     $30,000 to $34,999    115755       2975                             31
# 8     $35,000 to $39,999    118563       2934                            262
# 9     $40,000 to $44,999    112751       2747                            154
# 10    $45,000 to $49,999    114744       2998                             52
# 11    $50,000 to $59,999    211329       3709                            168
# 12    $60,000 to $74,999    267360       4504                            138
# 13    $75,000 to $99,999    357378       4514                            101
# 14  $100,000 to $124,999    257232       4293                            125
# 15  $125,000 to $149,999    169567       3100                             16
# 16  $150,000 to $199,999    182209       3522                             46
# 17      $200,000 or more    197980       3847                             11
#
#    Unnamed: 4 Census Tract 202.01, Anderson, TN Unnamed: 6  \
# 0       Error                             Value      Error
# 1         225                              2029        160
# 2          90                                93         73
# 3          52                                28         35
# 4          42                                26         30
# 5          48                                74         57
# 6          73                                24         24
# 7          26                                 0         14
# 8         165                                54         42
# 9         110                                89         57
# 10         43                                86         62
# 11         88                               151         76
# 12         69                               219         85
# 13         53                               124         73
# 14         79                               242         94
# 15         18                               195        114
# 16         33                               256         81
# 17         16                               368        140
#
#    Census Tract 202.02, Anderson, TN Unnamed: 8  \
# 0                              Value      Error
# 1                               1951        235
# 2                                235        127
# 3                                159        126
# 4                                  7         13
# 5                                 13         20
# 6                                101        126
# 7                                 48         51
# 8                                 40         46
# 9                                 33         38
# 10                               140        165
# 11                                74         51
# 12                               257        158
# 13                               164         97
# 14                               134         77
# 15                               129        106
# 16                               295        146
# 17                               122         67
#
#    Census Tract 203, Anderson, TN  ... Census Tract 309.05, Wilson, TN  \
# 0                           Value  ...                           Value
# 1                            1567  ...                            1925
# 2                              25  ...                              38
# 3                              95  ...                               0
# 4                              56  ...                               0
# 5                              30  ...                              36
# 6                              84  ...                               0
# 7                              65  ...                              17
# 8                              74  ...                              24
# 9                              46  ...                              63
# 10                             53  ...                              61
# 11                            173  ...                              32
# 12                            170  ...                              88
# 13                            280  ...                             440
# 14                            174  ...                             254
# 15                            106  ...                             326
# 16                             93  ...                             297
# 17                             43  ...                             249
#
#    Unnamed: 3396 Census Tract 309.06, Wilson, TN Unnamed: 3398  \
# 0          Error                           Value         Error
# 1            288                            1963           244
# 2             64                               0            19
# 3             19                              21            35
# 4             19                              17            30
# 5             60                              28            45
# 6             19                               0            19
# 7             28                              60            49
# 8             28                               0            19
# 9             65                              68            81
# 10            50                              35            59
# 11            42                             175           104
# 12            48                             279           161
# 13           268                             279           163
# 14           100                             142           131
# 15           129                             209           102
# 16            99                             164           129
# 17           129                             486           161
#
#    Census Tract 309.07, Wilson, TN Unnamed: 3400  \
# 0                            Value         Error
# 1                             2513           276
# 2                              109            89
# 3                               60            58
# 4                               59            68
# 5                               30            50
# 6                               83            66
# 7                               89            71
# 8                               34            40
# 9                               29            46
# 10                               0            19
# 11                             145            91
# 12                             304           126
# 13                             645           251
# 14                             304           114
# 15                             130            67
# 16                             330           144
# 17                             162            90
#
#    Census Tract 309.08, Wilson, TN Unnamed: 3402 Census Tract 310, Wilson, TN  \
# 0                            Value         Error                        Value
# 1                             3124           432                         2365
# 2                              133            92                          159
# 3                               61           102                          174
# 4                               46            52                          124
# 5                                0            19                           39
# 6                              182           152                           62
# 7                               41            41                          115
# 8                               33            54                           25
# 9                               72            84                           61
# 10                               9            25                           59
# 11                              94           104                          115
# 12                             232           141                          245
# 13                             445           182                          483
# 14                             566           249                          314
# 15                             279           167                           75
# 16                             510           235                          144
# 17                             421           259                          171
#
#    Unnamed: 3404
# 0          Error
# 1            373
# 2            106
# 3            158
# 4             75
# 5             32
# 6             40
# 7             71
# 8             23
# 9             54
# 10            51
# 11            54
# 12            98
# 13           266
# 14           137
# 15            63
# 16            80
# 17            85
#
# [18 rows x 3405 columns]

# %%
census_income_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Columns: 3405 entries, Unnamed: 0 to Unnamed: 3404
# dtypes: object(3405)
# memory usage: 479.0+ KB
